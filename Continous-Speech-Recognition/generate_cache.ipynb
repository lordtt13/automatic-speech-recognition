# %%
from audio_reader import AudioReader

# %%
# Here we only have one speaker, will expand in future
speakers_sub_list = 'p225'.split(',')

AudioReader(audio_dir = 'vctk-p225',
            sample_rate = 8000,
            cache_dir = 'cache',
            speakers_sub_list = speakers_sub_list)
# Out:
# Initializing AudioReader()
# audio_dir = vctk-p225
# cache_dir = cache
# sample_rate = 8000
# speakers_sub_list = ['p225']
# Nothing found at cache. Generating all the caches now.
# Found 231 files in total in vctk-p225.
# 231 files correspond to the speaker list ['p225'].
# [DUMP AUDIO] cache/p225_001_cache.pkl
# [DUMP AUDIO] cache/p225_002_cache.pkl
# [DUMP AUDIO] cache/p225_003_cache.pkl
# [DUMP AUDIO] cache/p225_004_cache.pkl
# [DUMP AUDIO] cache/p225_005_cache.pkl
# [DUMP AUDIO] cache/p225_006_cache.pkl
# [DUMP AUDIO] cache/p225_007_cache.pkl
# [DUMP AUDIO] cache/p225_008_cache.pkl
# [DUMP AUDIO] cache/p225_009_cache.pkl
# [DUMP AUDIO] cache/p225_010_cache.pkl
# [DUMP AUDIO] cache/p225_011_cache.pkl
# [DUMP AUDIO] cache/p225_012_cache.pkl
# [DUMP AUDIO] cache/p225_013_cache.pkl
# [DUMP AUDIO] cache/p225_014_cache.pkl
# [DUMP AUDIO] cache/p225_016_cache.pkl
# [DUMP AUDIO] cache/p225_017_cache.pkl
# [DUMP AUDIO] cache/p225_018_cache.pkl
# [DUMP AUDIO] cache/p225_019_cache.pkl
# ...
