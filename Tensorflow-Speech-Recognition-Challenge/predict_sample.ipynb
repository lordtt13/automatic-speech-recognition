# %%
import random
import pickle

import IPython.display as ipd

from custom_predict import predict

# %%
all_wav = pickle.load(open( "wav.pickle", "rb" ))
labels, classes = pickle.load(open( "labels_clases.pickle", "rb" ))

# %%
index = random.choice(range(all_wav.shape[0]))
samples = all_wav[index].ravel()
print("Audio:", classes[labels[index]])
# Out:
# Audio: stop

# %%
ipd.Audio(samples, rate = 8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Text:", predict(samples))
# Out:
# Text: stop
